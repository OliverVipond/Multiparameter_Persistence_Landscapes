# %%
from helper_functions import sample_circle_disc
import numpy as np

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Persistent Homology and Noise

# %% [markdown]
# ### 1D Examples

# %%
from one_parameter_plotting import Rips_Filtration
# Out:
# /home/ollie/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence

# %% [markdown]
# ### Single Loop

# %%
points = sample_circle_disc(1,100)
show(Rips_Filtration(points,[0.01,2]))
# Out:
#   <div class="bk-root" id="59111ad3-9523-440c-ac78-243f608a04c1" data-root-id="13069"></div>

# %% [markdown]
# ### Multiple Loops Different Sizes

# %%
points = np.vstack((sample_circle_disc(1,100, radius = 1, centre = [0,1]),
                    sample_circle_disc(1,100, radius = 0.5, centre = [0,-1])))

show(Rips_Filtration(points,[0.01,2]))
# Out:
#   <div class="bk-root" id="8eef68bd-358b-4d1e-b941-c78537079ba7" data-root-id="60833"></div>

# %% [markdown]
# ## Adding Noise to 1D

# %%
points = sample_circle_disc(0.8,100)
show(Rips_Filtration(points,[0.01,2]))
# Out:
#   <div class="bk-root" id="1ee306a7-3960-47ae-aac3-b9e23b204f16" data-root-id="80636"></div>

# %%
points = np.vstack((sample_circle_disc(0.8,100, radius = 1, centre = [0,1]),
                    sample_circle_disc(0.8,100, radius = 0.5, centre = [0,-1])))

show(Rips_Filtration(points,[0.01,2]))
# Out:
#   <div class="bk-root" id="ec964323-ea37-4573-9b6f-64e6884ca9d8" data-root-id="135726"></div>

# %% [markdown]
# # 2D Persistence

# %% [markdown]
# ### Single Loop with Noise Revisited

# %%
from multiparameter_landscape_plotting import Rips_Codensity_Bifiltration

# %%
points = sample_circle_disc(0.8,100)
show(Rips_Codensity_Bifiltration(points,[0,2],15,maxind=3, dim = 1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-749cbf787f46> in <module>
#       1 points = sample_circle_disc(0.8,100)
# ----> 2 show(Rips_Codensity_Bifiltration(points,[0,2],15,maxind=3, dim = 1))
#
# ~/Documents/RIVET/Git_synced_MultiPersLandscapes/Multiparameter_Persistence_Landscapes/multiparameter_landscape_plotting.py in Rips_Codensity_Bifiltration(points, radius_range, kNN, maxind, dim)
#     704     ]
#     705
# --> 706     landscape_plots = plot_multiparameter_landscapes(multi_landscape, indices=[1, maxind], TOOLTIPS=TOOLTIPS)
#     707
#     708     for plot in landscape_plots.children:
#
# ~/Documents/RIVET/Git_synced_MultiPersLandscapes/Multiparameter_Persistence_Landscapes/multiparameter_landscape_plotting.py in plot_multiparameter_landscapes(multi_landscape, indices, TOOLTIPS)
#     104
#     105     for k in range(indices[0] - 1, indices[1]):
# --> 106         plots.append(plot_a_two_parameter_landscape(multi_landscape, k, TOOLTIPS=TOOLTIPS))
#     107
#     108     for k in range(0, len(plots)):
#
# ~/Documents/RIVET/Git_synced_MultiPersLandscapes/Multiparameter_Persistence_Landscapes/multiparameter_landscape_plotting.py in plot_a_two_parameter_landscape(multi_landscape, index, TOOLTIPS)
#      62
#      63     source = ColumnDataSource(
# ---> 64         data=dict(image=[landscape_matrix_to_img(multi_landscape.landscape_matrix[index, :, :])],
#      65                   x=[multi_landscape.bounds.lower_left[0]],
#      66                   y=[multi_landscape.bounds.lower_left[1]],
#
# TypeError: 'method' object is not subscriptable
